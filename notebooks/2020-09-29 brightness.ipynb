# %%
# %load_ext autoreload
# %autoreload 2

import rawpy, imageio
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (12, 18)

raw = rawpy.imread('image.RAF')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rgb = raw.postprocess(no_auto_bright=True,use_auto_wb=False,gamma=None)

# %%
plt.imshow(rgb)

# %%
rgb.max()
# Out:
# 255

# %%
bright = rgb + 20

# %%
plt.hist(rgb[:, :, 0].flatten(), color="r", alpha=0.5)
plt.hist(rgb[:, :, 1].flatten(), color="g", alpha=0.5)
plt.hist(rgb[:, :, 2].flatten(), color="b", alpha=0.5)
# Out:
# (array([2.5477517e+07, 3.9156100e+05, 8.5656000e+04, 7.5200000e+03,
#         3.7020000e+03, 3.3210000e+03, 3.5770000e+03, 3.6110000e+03,
#         4.1690000e+03, 6.5186000e+04]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bright[:, :, 0].flatten(), color="r", alpha=0.5)
plt.hist(bright[:, :, 1].flatten(), color="g", alpha=0.5)
plt.hist(bright[:, :, 2].flatten(), color="b", alpha=0.5)
# Out:
# (array([2.2901467e+07, 2.7851830e+06, 2.7273300e+05, 6.2853000e+04,
#         5.0490000e+03, 3.4810000e+03, 3.4710000e+03, 3.5080000e+03,
#         3.7940000e+03, 4.2810000e+03]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.imshow(bright)
